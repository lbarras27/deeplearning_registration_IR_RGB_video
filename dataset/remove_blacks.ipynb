# %%
import util
import numpy as np
import os, sys
import cv2
import matplotlib.pyplot as plt

# %%
path = "DATA3/videos7/"
imgs_rgb, imgs_ir = util.loadDataset2(path, "RGB_frames", "IR_frames")

# %%
imgs_ir.shape
# Out:
# (13689, 240, 320, 3)

# %%
imgs_rgb_nb, imgs_rgb_b, id_noBlack_frames = util.splitBlackImages(imgs_rgb, 20, 0.9)

# %%
imgs_rgb_nb.shape
# Out:
# (10445, 240, 320, 3)

# %%
plt.figure(figsize=(15,15))
plt.subplot(121)

plt.imshow(imgs_rgb_nb[0])

plt.subplot(122)

plt.imshow(imgs_rgb_b[3080])

# %%
for i in range(0, imgs_rgb_nb.shape[0]):
    cv2.imwrite(path+"RGB_frames_noBlack/frame"+str(i)+".jpg", imgs_rgb_nb[i])

# %%
for i, j in enumerate(id_noBlack_frames):
    cv2.imwrite(path+"IR_frames_noBlack/frame"+str(i)+".jpg", imgs_ir[j])
